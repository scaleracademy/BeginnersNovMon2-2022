# %% [markdown]
# <a href="https://colab.research.google.com/github/scaleracademy/BeginnersNovMon2-2022/blob/main/Function2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#quiz
# What will be the output of the following code?
function random():
    return True

random()
# Out:
#   File "<ipython-input-1-1188382f29f8>", line 3
#     function random():
#              ^
# SyntaxError: invalid syntax

# %%
def random():
    return True

random()
# Out:
# True

# %%
def random():
    return 0

random()
# Out:
# 0

# %%
def random():
    print('hello')

print(random())
# Out:
# hello
# None

# %%
#quiz
#What will be the output of the following piece of code?
def abc:
    return "I am a function!"

abc()
# Out:
#   File "<ipython-input-5-a6a6aa1c51cc>", line 3
#     def abc:
#            ^
# SyntaxError: invalid syntax

# %%
def abc():
    return "I am a function!"
    

print(abc())
# Out:
# None

# %%
#quiz
def f(a, b, c):
    print((a + b + c)/3)
f(3, 5, 7)
# Out:
# 5.0

# %%
#quiz
# What is output of the following code snippet?
def power(number,exponent):
    return number**exponent

print(power(3, 2))
# Out:
# 9

# %% [markdown]
# keyword arguments & positional arguments

# %%
def introduce_family(me, father,mother,sibling):
  print('me=',me)
  print('father=',father)
  print('mother=',mother)
  print('sibling=',sibling)

# %%
introduce_family('A','B','C','D')#POSITIONAL ARGUMENT
# Out:
# me= A
# father= B
# mother= C
# sibling= D

# %%
def introduce_family(me, father,mother,sibling):
  print('me=',me)
  print('father=',father)
  print('mother=',mother)
  print('sibling=',sibling)

# %%
#keyword arguments
introduce_family(father='A',mother='B',sibling='C',me='D')
# Out:
# me= D
# father= A
# mother= B
# sibling= C

# %%
def random(a,b,c,d):
  print(a,b,c,d)

# %%
random(1,5,2,3)
# Out:
# 1 5 2 3

# %%
random(b=3,a=2,c=5,d=1)
# Out:
# 2 3 5 1

# %%
help(random)
# Out:
# Help on function random in module __main__:
#
# random(a, b, c, d)

# %%
def random(a,b,c,d):
  print(a,b,c,d)

# %%
random(7,2,d=5,c=3) #position => keyword
# Out:
# 7 2 3 5

# %%
random(7,2,a=5,c=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-25cfa42c5986> in <module>
# ----> 1 random(7,2,a=5,c=3)
#
# TypeError: random() got multiple values for argument 'a'

# %%
random(7,2,c=3,b=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-dbd7293e4d57> in <module>
# ----> 1 random(7,2,c=3,b=4)
#
# TypeError: random() got multiple values for argument 'b'

# %%
def random(a,b,c,d):
  print(a,b,c,d)

# %%
random(a=1,b=2,3,4)
# Out:
#   File "<ipython-input-22-15a98b1f23c2>", line 1
#     random(a=1,b=2,3,4)
#                    ^
# SyntaxError: positional argument follows keyword argument

# %%
#quiz
# What is output of the following code snippet?
def power(number,exponent):
    return number**exponent

power(exponent=2, number=3)
# Out:
# 9

# %% [markdown]
# #default keywords

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print('deepakkumar','patil',sep='#',end='@')
print('khim')
# Out:
# deepakkumar#patil@khim

# %%
print('deepakkumar','patil')
print('khim')
# Out:
# deepakkumar patil
# khim

# %%
# p = principal
# r = rate of interest
#t = time
def simple_interest(p,r,t):
  return (p*r*t/100)

# %%
si = simple_interest(100,2,10)
print(si)
# Out:
# 20.0

# %%
def simple_interest(p,r,t):
  print(p*r*t/100)

# %%
si = simple_interest(100,2,10)
print(si)
# Out:
# 20.0
# None

# %%
# p = principal
# r = rate of interest
#t = time
def simple_interest(p,t,r=10):
  return (p*r*t/100)

# %%
simple_interest(100,5)
# Out:
# 50.0

# %%
simple_interest(100,5,5)
# Out:
# 25.0

# %%
# p = principal
# r = rate of interest
#t = time
def simple_interest(p=50,t=1,r=10):
  return (p*r*t/100)

# %%
print(simple_interest())
print(simple_interest(1000))
print(simple_interest(100,2))
print(simple_interest(200,1,30))
# Out:
# 5.0
# 100.0
# 20.0
# 60.0

# %%
def simple_interest(p=50,t,r=10):
  return (p*r*t)/100
# Out:
#   File "<ipython-input-45-9715f42b4ccf>", line 1
#     def simple_interest(p=50,t,r=10):
#                         ^
# SyntaxError: non-default argument follows default argument

# %%
# positional => keyword => calling the function
# non-default => default => defining the function

# %%
#quiz
# What is the output of following code snippet?
def power(x, e=1):
    return x ** e

power(3, 3)
# Out:
# 27

# %%
#quiz
def print_date(d, m, y, style=0):
    if style == 0:  # American
        print(m, '/', d, '/', y)
    elif style == 1:  # European
        print(d, '/', m, '/', y)
    else:
        print('Invalid Style')
print_date(30, 5, 2022)
# Out:
# 5 / 30 / 2022

# %%
# A
# 30/5/22
# B
# 30/5/2022
# C
# 5/30/2022

# %%
def print_date(d=1, m=1, y=2022, s=0):
    if s == 0:  # American
        print(m, '/', d, '/', y)
    elif s == 1:  # European
        print(d, '/', m, '/', y)
    else:
        print('Invalid Style')

print_date(d=30, y=2022)
# Out:
# 1 / 30 / 2022

# %% [markdown]
# #scope of variable

# %%
# scope of variable - region within which a variable can be used

# global variable
chief_of_house = "mother"

def change_chief():
    # local variable
    chief_of_house = "father"
    print("Inside the function -", chief_of_house)
    
    
change_chief()
print("Outside the function -", chief_of_house)
# Out:
# Inside the function - father
# Outside the function - mother

# %%
# scope of variable - region within which a variable can be used

# global variable
chief_of_house = "mother"

def change_chief():
    # local variable
    # chief_of_house = "father"
    print("Inside the function -", chief_of_house)
    
    
change_chief()
print("Outside the function -", chief_of_house)
# Out:
# Inside the function - mother
# Outside the function - mother

# %%
# global variable
# chief = "mother"

def change_chief():
    # local variable
    chief = "father"
    print("Inside the function -", chief)
    
    
change_chief()
print("Outside the function -", chief)
# Out:
# Inside the function - father
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-3f789f4c90fb> in <module>
#       9
#      10 change_chief()
# ---> 11 print("Outside the function -", chief)
#
# NameError: name 'chief' is not defined

# %%
# global variable
chief_of_house = "mother"

def change_chief():
    # local variable
    global chief_of_house 
    chief_of_house = "father"
    print("Inside the function -", chief_of_house)
    
    
change_chief()
print("Outside the function -", chief_of_house)
# Out:
# Inside the function - father
# Outside the function - father

# %%
#quiz
# What does the following code print?
a = 10
def f():
    print('Hello')
    b = 20
f()
print(a)
print(b)
# Out:
# Hello
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-01e6aff87355> in <module>
#       7 f()
#       8 print(a)
# ----> 9 print(b)
#
# NameError: name 'b' is not defined

# %%
# What would be the output of the following code?
a = 10

def calculator(number):
    return (number * 10)


num= calculator(a)
print(num)
print(a)
# Out:
# 100
# 10

# %%
#doubts
# What would be the output of the following code?
a = int(input())

def calculator(number):
  
    return (number * 10)


num= calculator(a)
print(num)
print(a)
# Out:
# 100
# 1000
# 100

# %%
#doubts
# What would be the output of the following code?
a = int(input())

def calculator(number):
    ''' this function is doing number *10'''
    print(number *10)
    # return (number * 10)


num= calculator(a)
print(num)
# print(a)
# Out:
# 100
# 1000
# None

# %%
help(calculator)
# Out:
# Help on function calculator in module __main__:
#
# calculator(number)
#     this function is doing number *10

# %%
a = int(input())

def calculator():
    return (number * 10)


num= calculator(a)
print(num)
print(a)
# Out:
# 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-a912586d481d> in <module>
#       5
#       6
# ----> 7 num= calculator(a)
#       8 print(num)
#       9 print(a)
#
# TypeError: calculator() takes 0 positional arguments but 1 was given

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.
